# %% [markdown]
# # Machine Translation with LSTM (seq2seq)
#
# This problem is from the last assignment of the [Udacity Deep Learning course](https://www.udacity.com/course/deep-learning--ud730). The idea is to build a sequence to sequence model using LSTMs that will convert sequences of words of the form:
#
#     the quick brown fox
#
# to this form:
#
#     eht kciuq nworb xof
#
# i.e., the characters of each word are reversed. This is a similar (although much simplified) scenario to machine translation where input words are in one language and output words are in another. However, the creation of training data has been simplified with this approach.
#
# One caveat with this approach is that we cannot make it a word based seq2seq model, since there is a 1 to 1 correspondence between the two "languages". Instead, we will create a character based seq2seq model so the model cannot depend on any regularity.
#
# The file name for the notebook is a reference to [The Shining](http://www.imdb.com/title/tt0081505/) in case you were wondering.
#
# ## Setup Imports

# %%
from __future__ import division, print_function
from keras.layers.core import Activation, Dense, RepeatVector
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import TimeDistributed
from keras.models import Sequential
from sklearn.cross_validation import train_test_split
import nltk
import numpy as np
# Out:
# Using Theano backend.

# %% [markdown]
# ## Extract Text from file
#
# We extract the list of words for use later. We also capture the vocabulary as we read it.

# %%
char_vocab = set(" ")
sentences = []
fin = open("../data/alice_in_wonderland.txt", "rb")
for line in fin:
    line = line.strip()
    if len(line) == 0:
        continue
    for sentence in nltk.sent_tokenize(line):
        words = []
        for word in nltk.word_tokenize(sentence):
            word = word.lower()
            words.append(word)
            for c in word:
                char_vocab.add(c)
        sentences.append(words)
fin.close()

vocab_size = len(char_vocab)
print("vocab size: %d" % (vocab_size))
# Out:
# vocab size: 45

# %% [markdown]
# ## Create text sequences
#
# Our input sequences are 4 words long. Here we construct the input and output training sequences from the text, and compute the maximum size of the sequence in characters.

# %%
def reverse_words(words):
    reversed_words = []
    for w in words:
        reversed_words.append("".join(reversed([c for c in w])))
    return reversed_words

nb_words_in_seq = 4
input_texts = []
output_texts = []
for sentence in sentences:
    ngrams = nltk.ngrams(sentence, nb_words_in_seq)
    for ngram in ngrams:
        input_texts.append(" ".join(ngram))
        output_texts.append(" ".join(reverse_words(ngram)))

maxlen = max([len(x) for x in input_texts])
print("maximum length of sequence: %d chars" % (maxlen))
# Out:
# maximum length of sequence: 36 chars

# %% [markdown]
# ## Create Lookup tables
#
# As mentioned earlier, we are going to build a character based seq2seq model. We use the vocabulary generated earlier to construct lookup tables for each character.

# %%
char2idx = dict((c, i) for i, c in enumerate(char_vocab))
idx2char = {v:k for k, v in char2idx.items()}

# %% [markdown]
# ## Vectorize sequences

# %%
X = np.zeros((len(input_texts), maxlen, vocab_size), dtype=np.bool)
Y = np.zeros((len(output_texts), maxlen, vocab_size), dtype=np.bool)
for i, input_text in enumerate(input_texts):
    input_text = input_text.ljust(maxlen)
    for j, ch in enumerate([c for c in input_text]):
        X[i, j, char2idx[ch]] = 1
for i, output_text in enumerate(output_texts):
    output_text = output_text.ljust(maxlen)
    for j, ch in enumerate([c for c in output_text]):
        Y[i, j, char2idx[ch]] = 1

# %% [markdown]
# ## Split data into training and test

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.3, random_state=0)
print(Xtrain.shape, Xtest.shape, Ytrain.shape, Ytest.shape)
# Out:
# (16621, 36, 45) (7124, 36, 45) (16621, 36, 45) (7124, 36, 45)

# %% [markdown]
# ## Build Model

# %%
model = Sequential()
model.add(LSTM(512, input_shape=(maxlen, vocab_size), return_sequences=False))
model.add(RepeatVector(maxlen))
model.add(LSTM(512, return_sequences=True))
model.add(TimeDistributed(Dense(vocab_size)))
model.add(Activation("softmax"))

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ## Evaluate Model

# %%
def decode_text(probas):
    text_seq = []
    for i in range(probas.shape[0]):
        idx = np.argmax(probas[i])
        text_seq.append(idx2char[idx])
    return "".join(text_seq).strip()

for iteration in range(51):
    print("=" * 50)
    print("Iteration-#: %d" % (iteration))
    model.fit(Xtrain, Ytrain, batch_size=128, nb_epoch=1, 
              verbose=0, validation_data=(Xtest, Ytest))
    for i in range(10):
        test_idx = np.random.randint(Xtest.shape[0])
        x_test = np.array([Xtest[test_idx, :, :]])
        y_test = np.array([Ytest[test_idx, :, :]])
        y_pred = model.predict([x_test], verbose=0)
        xtest_text = decode_text(x_test[0])
        ytest_text = decode_text(y_test[0])
        ypred_text = decode_text(y_pred[0])
        print("input: [%s], expected: [%s], got: [%s]" % 
              (xtest_text, ytest_text, ypred_text))
# Out:
# ==================================================
# Iteration-#: 0
# input: [and legs in all], expected: [dna sgel ni lla], got: [e]
# input: [sea as you can], expected: [aes sa uoy nac], got: [e]
# input: [of the conversation .], expected: [fo eht noitasrevnoc .], got: [ee]
# input: ['oh , hush !], expected: [ho' , hsuh !], got: []
# input: [of voices asked .], expected: [fo seciov deksa .], got: [e]
# input: [very turn-up nose ,], expected: [yrev pu-nrut eson ,], got: [ee]
# input: [as he shook his], expected: [sa eh koohs sih], got: [e]
# input: [what they will do], expected: [tahw yeht lliw od], got: [e]
# input: [very uncomfortable , and], expected: [yrev elbatrofmocnu , dna], got: [eee]
# input: [grow smaller , i], expected: [worg rellams , i], got: [e]
# ==================================================
# Iteration-#: 1
# input: [a duck and a], expected: [a kcud dna a], got: [e]
# input: [the dormouse slowly opened], expected: [eht esuomrod ylwols denepo], got: [eeee                  eeee]
# input: [rustled at her feet], expected: [deltsur ta reh teef], got: [ee               e]
# input: [was quite silent for], expected: [saw etiuq tnelis rof], got: [ee               ee]
# input: [no more , whatever], expected: [on erom , revetahw], got: [ee]
# input: [as the rabbit ,], expected: [sa eht tibbar ,], got: [e]
# input: [for the rest of], expected: [rof eht tser fo], got: [e]
# input: [above the world you], expected: [evoba eht dlrow uoy], got: [ee               e]
# input: [: and how she], expected: [: dna woh ehs], got: [e]
# input: [seem to be ''], expected: [mees ot eb ''], got: [e]
# ==================================================
# Iteration-#: 2
# input: [, 'and that 's], expected: [, dna' taht s'], got: [,         ee]
# input: [think i should understand], expected: [kniht i dluohs dnatsrednu], got: [eee               eeeee]
# input: [, ' said the], expected: [, ' dias eht], got: [,]
# input: [alice watched the white], expected: [ecila dehctaw eht etihw], got: [eee              eeeee]
# input: [he with his nose], expected: [eh htiw sih eson], got: [e             e]
# input: ['let 's go on], expected: [tel' s' og no], got: [e]
# input: [of voices -- 'hold], expected: [fo seciov -- dloh'], got: [eee]
# input: [, which she found], expected: [, hcihw ehs dnuof], got: [,           eeee]
# input: [soup of the evening], expected: [puos fo eht gnineve], got: [ee             eee]
# input: [soon the rabbit noticed], expected: [noos eht tibbar deciton], got: [eee               eeee]
# ==================================================
# Iteration-#: 3
# input: [that she had put], expected: [taht ehs dah tup], got: [ehht ee]
# input: [' said the mock], expected: [' dias eht kcom], got: [, dnaa eeeeeeee]
# input: [was near enough to], expected: [saw raen hguone ot], got: [tht  e        ee]
# input: [a large mushroom growing], expected: [a egral moorhsum gniworg], got: [t  eeeeeeeeeeeeeeeeee]
# input: [his shining tail ,], expected: [sih gninihs liat ,], got: [eii   e       aaa]
# input: [it fills the whole], expected: [ti sllif eht elohw], got: [th eeeeeeeeeeeeee]
# input: [to begin . '], expected: [ot nigeb . '], got: [t]
# input: [as if she were], expected: [sa fi ehs erew], got: [t  eeeeeeeeeee]
# input: [soon the rabbit noticed], expected: [noos eht tibbar deciton], got: [too   oo        oooeee]
# input: [and rapped loudly at], expected: [dna deppar ylduol ta], got: [daa  llll]
# ==================================================
# Iteration-#: 4
# input: [some of them hit], expected: [emos fo meht tih], got: [eooo  o   tthhht]
# input: [him , and said], expected: [mih , dna dias], got: [sii ,     aaaa]
# input: [moving them about as], expected: [gnivom meht tuoba sa], got: [enoooo  rtt      tt]
# input: ['there 's a large], expected: [ereht' s' a egral], got: [eeeeeh  ,      aaa]
# input: [three times over to], expected: [eerht semit revo ot], got: [eeeht  eeee      oo]
# input: [speak first , 'why], expected: [kaeps tsrif , yhw'], got: [eeuur   ia     aa]
# input: [, ' said alice], expected: [, ' dias ecila], got: [,   iaaaaiiaaa]
# input: [, who had been], expected: [, ohw dah neeb], got: [,  a   h   hha]
# input: [of hers that you], expected: [fo sreh taht uoy], got: [oo  ehh      hht]
# input: [dormouse say ? '], expected: [esuomrod yas ? '], got: [dnoooooo  o]
# ==================================================
# Iteration-#: 5
# input: [except the lizard ,], expected: [tpecxe eht drazil ,], got: [eeeerr  eet        ,]
# input: [, ' said alice], expected: [, ' dias ecila], got: [, ' diia llllla]
# input: [or soldiers , or], expected: [ro sreidlos , ro], got: [oo serrrrss]
# input: ['m grown up now], expected: [m' nworg pu won], got: [t' gnngg ooo  o]
# input: [themselves flat upon their], expected: [sevlesmeht talf nopu rieht], got: [eeeeeeeee              oo]
# input: [ann , what are], expected: [nna , tahw era], got: [nnn ,a aaa eeaa]
# input: [them alice recognised the], expected: [meht ecila desingocer eht], got: [eeht eeeee  eeii  eeeeeee]
# input: [, ' said the], expected: [, ' dias eht], got: [, ' dia  eeht]
# input: [bright flower-beds and the], expected: [thgirb sdeb-rewolf dna eht], got: [eeuubb yeuurr           aa]
# input: [have to ask them], expected: [evah ot ksa meht], got: [eeaa ea  eh  eeh]
# ==================================================
# Iteration-#: 6
# input: [was looking for the], expected: [saw gnikool rof eht], got: [saw gnoooo oo  ttt]
# input: [and sometimes shorter ,], expected: [dna semitemos retrohs ,], got: [dna eeetms eeett eeem]
# input: [dormouse , who was], expected: [esuomrod , ohw saw], got: [ssooooo ,  ea  eh]
# input: [alice a good opportunity], expected: [ecila a doog ytinutroppo], got: [elaa  a ooo oottteeoooo]
# input: [wish you would n't], expected: [hsiw uoy dluow t'n], got: [tlww sow ooo  ooo]
# input: [, 'it 'll never], expected: [, ti' ll' reven], got: [, ei' ee  eeee]
# input: [i 'm on the], expected: [i m' no eht], got: [i oo eo ee]
# input: [it does n't understand], expected: [ti seod t'n dnatsrednu], got: [t' eit  dnd ddddeeeee]
# input: [only difficulty was ,], expected: [ylno ytluciffid saw ,], got: [doo  dlullll       ,]
# input: [door , and the], expected: [rood , dna eht], got: [doo ,  da ehh]
# ==================================================
# Iteration-#: 7
# input: [, there were no], expected: [, ereht erew on], got: [, eeht  eew  o]
# input: [' she said to], expected: [' ehs dias ot], got: [' ehs dit  o]
# input: [she felt sure it], expected: [ehs tlef erus ti], got: [eht ellf  eit ti]
# input: [with the clock .], expected: [htiw eht kcolc .], got: [ttiw eht dllo]
# input: [for the baby ,], expected: [rof eht ybab ,], got: [foo eht trab ,]
# input: [silence , broken only], expected: [ecnelis , nekorb ylno], got: [deiieee ,  noooo ooo]
# input: [it at last ,], expected: [ti ta tsal ,], got: [ta tt tlat ,]
# input: [, who seemed to], expected: [, ohw demees ot], got: [, eh  eeeo]
# input: [back-somersault in at the], expected: [tluasremos-kcab ni ta eht], got: [tetttmmm tttttaaa     tttt]
# input: [ravens and writing-desks ,], expected: [snevar dna sksed-gnitirw ,], got: [dnaree  nn gniiiisssssns]
# ==================================================
# Iteration-#: 8
# input: [i or she should], expected: [i ro ehs dluohs], got: [o eh ehs scuus]
# input: [, though she felt], expected: [, hguoht ehs tlef], got: [, thhtot ehh eehs]
# input: [not dare to disobey], expected: [ton erad ot yebosid], got: [dnn dnot tt eeeuuu]
# input: [her foot , that], expected: [reh toof , taht], got: [eeh foof , thht]
# input: [said the march hare], expected: [dias eht hcram erah], got: [dias eht ecaaa rrah]
# input: [she should meet the], expected: [ehs dluohs teem eht], got: [ehs dsuoos eehht hh]
# input: [after it , and], expected: [retfa ti , dna], got: [eettf fi , dna]
# input: [looking over their shoulders], expected: [gnikool revo rieht sredluohs], got: [dnioooo eeot eeet   eeeerrr]
# input: [peeping anxiously into her], expected: [gnipeep ylsuoixna otni reh], got: [gnieeeg yniipooo   ooo   o]
# input: ['you ought to be], expected: [uoy' thguo ot eb], got: [uuy' tuuou to tt]
# ==================================================
# Iteration-#: 9
# input: [if nothing had happened], expected: [fi gnihton dah deneppah], got: [oo gniiii  dah  eeeeraa]
# input: [, who had been], expected: [, ohw dah neeb], got: [, hhw dhh dno]
# input: [the duchess replied ,], expected: [eht ssehcud deilper ,], got: [eht eeeuhs  deelii  ,]
# input: [to see that the], expected: [ot ees taht eht], got: [ot eet tett tat]
# input: [being such a tiny], expected: [gnieb hcus a ynit], got: [tnibb niib t  taa]
# input: [the mock turtle :], expected: [eht kcom eltrut :], got: [eht kcom tltttt ,]
# input: [a great crowd assembled], expected: [a taerg dworc delbmessa], got: [, eehha  daaa  llelrrac]
# input: [see if she meant], expected: [ees fi ehs tnaem], got: [ees es eht eiii]
# input: [then a voice she], expected: [neht a eciov ehs], got: [ehht a eceee  hh]
# input: [; and the second], expected: [; dna eht dnoces], got: [, dna eht ddnuu]
# ==================================================
# Iteration-#: 10
# input: [' thought alice ,], expected: [' thguoht ecila ,], got: [' thhhht  cclaa,]
# input: [followed by a very], expected: [dewollof yb a yrev], got: [ylloooo fa    eeeb]
# input: [walked off together .], expected: [deklaw ffo rehtegot .], got: [dlllll fo eeefee ef]
# input: [cats could grin .], expected: [stac dluoc nirg .], got: [tla  duua nnnn .]
# input: [you wo n't '], expected: [uoy ow t'n '], got: [uoy o' o' '']
# input: [kill it in a], expected: [llik ti ni a], got: [kkkk t  i i]
# input: [said very politely ,], expected: [dias yrev yletilop ,], got: [dias yeey yllleee  ,]
# input: [said the dormouse ,], expected: [dias eht esuomrod ,], got: [dias eht eeomooo  ,]
# input: [the chimney ! '], expected: [eht yenmihc ! '], got: [eht neeeea  ''']
# input: [was : at first], expected: [saw : ta tsrif], got: [ta ,    thhff]
# ==================================================
# Iteration-#: 11
# input: [the first sentence in], expected: [eht tsrif ecnetnes ni], got: [eht eeetf  eeieeei  ni]
# input: [great question certainly was], expected: [taerg noitseuq ylniatrec saw], got: [nneeb gnittrrr  liiiaa   aaa]
# input: [hastily , just in], expected: [ylitsah , tsuj ni], got: [tlatahh , tuui si]
# input: ['is to grow to], expected: [si' ot worg ot], got: [ti' ot toog oo]
# input: [about her other little], expected: [tuoba reh rehto elttil], got: [ttuoa eht elerr  lltit]
# input: [blows hurt it or], expected: [swolb truh ti ro], got: [lloow ttow to fo]
# input: [mentioned me to him], expected: [denoitnem em ot mih], got: [nninneenm oo ttt ti]
# input: [' said alice ,], expected: [' dias ecila ,], got: [' dias ecila ,]
# input: [on being pinched by], expected: [no gnieb dehcnip yb], got: [ni nniv  eeiea  eub]
# input: [their names were elsie], expected: [rieht seman erew eisle], got: [eeitt eeeee eeee  eees]
# ==================================================
# Iteration-#: 12
# input: [, it must be], expected: [, ti tsum eb], got: [, ti tuum em]
# input: [the jury-box , or], expected: [eht xob-yruj , ro], got: [eht roorrrr  - da]
# input: [in that case i], expected: [ni taht esac i], got: [ti taht ecaa a]
# input: [about as she spoke], expected: [tuoba sa ehs ekops], got: [tuuba sa ehs eeoos]
# input: [sharp little chin into], expected: [prahs elttil nihc otni], got: [llaaa ecittt niiit nii]
# input: [, as she swam], expected: [, sa ehs maws], got: [, sa ehs saaw]
# input: [forgotten the words .], expected: [nettogrof eht sdrow .], got: [gntttrof eht  eeew]
# input: [and ran off ,], expected: [dna nar ffo ,], got: [dna raa fof f]
# input: [king , 'and do], expected: [gnik , dna' od], got: [nnik , dnad dod]
# input: [replied , so eagerly], expected: [deilper , os ylregae], got: [eeeleep , o  yeerrrr]
# ==================================================
# Iteration-#: 13
# input: [as she could ,], expected: [sa ehs dluoc ,], got: [sa ehs dluoc ,]
# input: [comes , to --], expected: [semoc , ot --], got: [emmmm    o  o']
# input: [the first sentence in], expected: [eht tsrif ecnetnes ni], got: [eht esrtf eeeteeen  n]
# input: [, ' said the], expected: [, ' dias eht], got: [, ' dias eht]
# input: [: 'no room !], expected: [: on' moor !], got: [, m'' room !]
# input: ['jury-men ' would have], expected: [nem-yruj' ' dluow evah], got: [yeohhmoo' - eeew ddnwww]
# input: [she was always ready], expected: [ehs saw syawla ydaer], got: [shs saw ylaaaw yrara]
# input: [her spectacles , and], expected: [reh selcatceps , dna], got: [ehh seessccccc  ,ddna]
# input: [and she tried hard], expected: [dna ehs deirt drah], got: [dna eht drrrh ddah]
# input: [, ) 'i 'll], expected: [, ) i' ll'], got: [, i li ll']
# ==================================================
# Iteration-#: 14
# input: [round goes the clock], expected: [dnuor seog eht kcolc], got: [dnuod eeoo eht kckol]
# input: [we used to call], expected: [ew desu ot llac], got: [eh dduw oa llal]
# input: [turtle would be so], expected: [eltrut dluow eb os], got: [eltuut dluow oo  o]
# input: [rather sleepy , and], expected: [rehtar ypeels , dna], got: [rettrr seepep , dna]
# input: [her with large round], expected: [reh htiw egral dnuor], got: [ehh taiw drira dnoor]
# input: [much to-night , i], expected: [hcum thgin-ot , i], got: [tcom hnihooo  , ,]
# input: ['it matters a good], expected: [ti' srettam a doog], got: [ti' eetrram oa ooo]
# input: [the duchess asked ,], expected: [eht ssehcud deksa ,], got: [eht seeuccd deees]
# input: [twinkle , twinkle --], expected: [elkniwt , elkniwt --], got: [nektiiw : ylikiiw --]
# input: [* * * *], expected: [* * * *], got: [* * * *]
# ==================================================
# Iteration-#: 15
# input: [bill 's got the], expected: [llib s' tog eht], got: [llil si tog eht]
# input: [it were nine o'clock], expected: [ti erew enin kcolc'o], got: [ti eeiw enod kckooc]
# input: [sort of way ,], expected: [tros fo yaw ,], got: [toos ot waw ,]
# input: [learn not to make], expected: [nrael ton ot ekam], got: [dnaaa noo ot kmam]
# input: [own child-life , and], expected: [nwo efil-dlihc , dna], got: [wow slillliiic , dna]
# input: [was so ordered about], expected: [saw os deredro tuoba], got: [saw oo dedoooo  tob]
# input: [gryphon , and the], expected: [nohpyrg , dna eht], got: [yoopyrg , dna eht]
# input: [you grow taller ,], expected: [uoy worg rellat ,], got: [uoy yooy llalal ,]
# input: [, with its legs], expected: [, htiw sti sgel], got: [, htiw siw slel]
# input: [because they would not], expected: [esuaceb yeht dluow ton], got: [dltuueb ehht wwoow ton]
# ==================================================
# Iteration-#: 16
# input: [had been to her], expected: [dah neeb ot reh], got: [dah neeb ot eht]
# input: [i 'm here !], expected: [i m' ereh !], got: [i m' eehh !]
# input: [a well ? '], expected: [a llew ? '], got: [a llew ? ']
# input: [life , never !], expected: [efil , reven !], got: [elil , evvvv !]
# input: [alice was not much], expected: [ecila saw ton hcum], got: [ecila saw ton ecum]
# input: [venture to say it], expected: [erutnev ot yas ti], got: [detteen ot tas si]
# input: [at the bottom of], expected: [ta eht mottob fo], got: [ta eht tooooo  o]
# input: [laid for a great], expected: [dial rof a taerg], got: [dial foo a taarg]
# input: [; if i 'm], expected: [; fi i m'], got: [; ii i  i]
# input: [looking for it ,], expected: [gnikool rof ti ,], got: [gnikool foo ti]
# ==================================================
# Iteration-#: 17
# input: [to pieces against one], expected: [ot seceip tsniaga eno], got: [fo esiii  nnatas too]
# input: [down , and was], expected: [nwod , dna saw], got: [wood , dna sas]
# input: [, i never heard], expected: [, i reven draeh], got: [, i eever raahh]
# input: [the gryphon : and], expected: [eht nohpyrg : dna], got: [eht nohpyrg , dna]
# input: [at once , in], expected: [ta ecno , ni], got: [ta ecoc , ni]
# input: [thing at all .], expected: [gniht ta lla .], got: [nniit aa laa]
# input: [just as i was], expected: [tsuj sa i saw], got: [tsuj s sa saw]
# input: ['i do n't see], expected: [i' od t'n ees], got: [i' od t'n ees]
# input: [queen added to one], expected: [neeuq dedda ot eno], got: [deeuq ddddd ot eoo]
# input: [this , and she], expected: [siht , dna ehs], got: [siht , dna ehs]
# ==================================================
# Iteration-#: 18
# input: [was in confusion ,], expected: [saw ni noisufnoc ,], got: [saw ni sniisoooc ,]
# input: [took the least notice], expected: [koot eht tsael eciton], got: [toot eht tctla etttit]
# input: [said , by way], expected: [dias , yb yaw], got: [dias , yy yad]
# input: [very provoking to find], expected: [yrev gnikovorp ot dnif], got: [yrvv gniknooov o  nnnf]
# input: [hurt it or not], expected: [truh ti ro ton], got: [trrr ti ot oon]
# input: ['now tell me ,], expected: [won' llet em ,], got: [wwn' llew ee ,]
# input: [: then it watched], expected: [: neht ti dehctaw], got: [: eeht ti eeccaac]
# input: [was the first to], expected: [saw eht tsrif ot], got: [saw eht ttrri ot]
# input: [head with great curiosity], expected: [daeh htiw taerg ytisoiruc], got: [eahw tahw ttrrr  siirrru]
# input: [was now , and], expected: [saw won , dna], got: [saw noo , dna]
# ==================================================
# Iteration-#: 19
# input: [' the dormouse went], expected: [' eht esuomrod tnew], got: [' eht ssuomooo  new]
# input: [see : that would], expected: [ees : taht dluow], got: [ees , eaht dluoa]
# input: [a little glass box], expected: [a elttil ssalg xob], got: [a elttil  uuaa  oa]
# input: [rabbit actually took a], expected: [tibbar yllautca koot a], got: [tlibaa llttaaa woo  aa]
# input: [the mouse was speaking], expected: [eht esuom saw gnikaeps], got: [eht ssumm saw gnikaeee]
# input: [the arm that was], expected: [eht mra taht saw], got: [eht taa hthh saw]
# input: [know when the race], expected: [wonk nehw eht ecar], got: [wook wahw eht eeaa]
# input: [are tarts made of], expected: [era strat edam fo], got: [rar sstta emas fo]
# input: [, i should n't], expected: [, i dluohs t'n], got: [, i dluhs  t']
# input: [( as she had], expected: [( sa ehs dah], got: [( sa ehs dah]
# ==================================================
# Iteration-#: 20
# input: [like an honest man], expected: [ekil na tsenoh nam], got: [ekil nn nnetoo sa]
# input: [, and the great], expected: [, dna eht taerg], got: [, dna eht taerg]
# input: [' alice said very], expected: [' ecila dias yrev], got: [' ecila diah yrev]
# input: [such nonsense ! '], expected: [hcus esnesnon ! '], got: [suut seennnnn ! ']
# input: [a mile high to], expected: [a elim hgih ot], got: [a ecil hhih ot]
# input: [some more tea ,], expected: [emos erom aet ,], got: [emom emef taa ,]
# input: ['dinah 's our cat], expected: [hanid' s' ruo tac], got: [dnih'' s'  uom ta]
# input: [rabbit , jumping up], expected: [tibbar , gnipmuj pu], got: [tibbrr , gniuupp p]
# input: [feather flock together .], expected: [rehtaef kcolf rehtegot .], got: [eeetfef foofo  eettoht .]
# input: [hint to time ,], expected: [tnih ot emit ,], got: [tnii ot emit ,]
# ==================================================
# Iteration-#: 21
# input: [alice , in a], expected: [ecila , ni a], got: [ecila , n  a]
# input: [, i beg your], expected: [, i geb ruoy], got: [, i eeb yuoy]
# input: [muchness -- you know], expected: [ssenhcum -- uoy wonk], got: [ssemccum -- woy wwon]
# input: [, as usual ,], expected: [, sa lausu ,], got: [, sa suus ,,]
# input: [at once : one], expected: [ta ecno : eno], got: [ta ecno : eno]
# input: [went to school in], expected: [tnew ot loohcs ni], got: [tnew ot nooooc ni]
# input: [, ' said the], expected: [, ' dias eht], got: [, ' dias eht]
# input: ['but they were in], expected: [tub' yeht erew ni], got: [tub' eeht erew ni]
# input: [paw , trying to], expected: [wap , gniyrt ot], got: [yaa , gniyat ot]
# input: [to write this down], expected: [ot etirw siht nwod], got: [ot ttiit siit dnod]
# ==================================================
# Iteration-#: 22
# input: [they were trying to], expected: [yeht erew gniyrt ot], got: [yeht yrew gnirrr ot]
# input: [up , alice dear], expected: [pu , ecila raed], got: [pp , dcila dead]
# input: [obstacle that came between], expected: [elcatsbo taht emac neewteb], got: [eltccccc ecat eetb eeeeebb]
# input: [you could see her], expected: [uoy dluoc ees reh], got: [uoy dluoc ees reh]
# input: [was no one listening], expected: [saw on eno gninetsil], got: [saw on noo gninnsnns]
# input: [' but checked herself], expected: [' tub dekcehc flesreh], got: [: oub eellehh deeleh]
# input: [consultation about this ,], expected: [noitatlusnoc tuoba siht ,], got: [nninooccooc  toooa  thh]
# input: [size : why ,], expected: [ezis : yhw ,], got: [ezis : yww ,]
# input: [, ' said the], expected: [, ' dias eht], got: [, ' dias eht]
# input: [out of its mouth], expected: [tuo fo sti htuom], got: [tuo fo tti htuom]
# ==================================================
# Iteration-#: 23
# input: [rabbit , with a], expected: [tibbar , htiw a], got: [tibbar , htiw a]
# input: [will you join the], expected: [lliw uoy nioj eht], got: [lliw uoy hnoj eht]
# input: [might do very well], expected: [thgim od yrev llew], got: [hggim oo yrev llew]
# input: [what you mean ,], expected: [tahw uoy naem ,], got: [tahw uoy naam ,]
# input: [to look about her], expected: [ot kool tuoba reh], got: [ot koob tuoba reh]
# input: [much to know ,], expected: [hcum ot wonk ,], got: [hcum ot wnnk ,]
# input: [gave a look askance], expected: [evag a kool ecnaksa], got: [evag a kook eckkaas]
# input: [hungry , in which], expected: [yrgnuh , ni hcihw], got: [yenyrg , oi hcihw]
# input: [of the house !], expected: [fo eht esuoh !], got: [fo eht esuos !]
# input: [the king : 'leave], expected: [eht gnik : evael'], got: [eht gnik : evvle']
# ==================================================
# Iteration-#: 24
# input: [corner , 'oh my], expected: [renroc , ho' ym], got: [rrrroc , oo' e']
# input: [all at once .], expected: [lla ta ecno .], got: [lla ta ecno .]
# input: [of little alice and], expected: [fo elttil ecila dna], got: [fo elttil ecila nna]
# input: [same thing as ``], expected: [emas gniht sa ``], got: [emas gniht si ``]
# input: [not so mad as], expected: [ton os dam sa], got: [ton ot das sa]
# input: [she tried to fancy], expected: [ehs deirt ot ycnaf], got: [ehs diirt ot ycnac]
# input: [eleventh day must have], expected: [htnevele yad tsum evah], got: [neeteeee tay ysom emhh]
# input: [' he said in], expected: [' eh dias ni], got: [' eh dias ni]
# input: [about it : it], expected: [tuoba ti : ti], got: [tuoba ti i ti]
# input: [' said alice .], expected: [' dias ecila .], got: [' dias ecila .]
# ==================================================
# Iteration-#: 25
# input: [began to tremble .], expected: [nageb ot elbmert .], got: [naeeb tt eebeee ..]
# input: [and i 'm i], expected: [dna i m' i], got: [dna i mi i]
# input: [and ran till she], expected: [dna nar llit ehs], got: [dna nna llit ehs]
# input: [trouble yourself to say], expected: [elbuort flesruoy ot yas], got: [yluuoon lluuoooo ot sas]
# input: [well enough ; do], expected: [llew hguone ; od], got: [llew gguuod ; oo]
# input: [well , and noticed], expected: [llew , dna deciton], got: [llew , nna ecntni]
# input: [and muchness -- you], expected: [dna ssenhcum -- uoy], got: [dna ssnhcuns --uuyy]
# input: [said the lory hastily], expected: [dias eht yrol ylitsah], got: [dias eht yyyr yltttah]
# input: [at your age ,], expected: [ta ruoy ega ,], got: [ta uuor ega ,]
# input: [fetch me a pair], expected: [hctef em a riap], got: [httaa eh a miap]
# ==================================================
# Iteration-#: 26
# input: [under the hedge .], expected: [rednu eht egdeh .], got: [dedud eht eeeeh .]
# input: [she squeezed herself up], expected: [ehs dezeeuqs flesreh pu], got: [ehs deeeuuus fleseu fuu]
# input: [soon finished off the], expected: [noos dehsinif ffo eht], got: [noos deessiif ffo eht]
# input: [over their heads .], expected: [revo rieht sdaeh .], got: [reoo rieht sdaah .]
# input: [with some curiosity .], expected: [htiw emos ytisoiruc .], got: [htiw rsom sliiirruc .]
# input: [and she did not], expected: [dna ehs did ton], got: [dna ehs did ton]
# input: [find that the hedgehog], expected: [dnif taht eht gohegdeh], got: [dnaf taht eht gehhgggg]
# input: [: 'fetch her here], expected: [: hctef' reh ereh], got: [: tchtab rrh rreh]
# input: [the king , and], expected: [eht gnik , dna], got: [eht gnik , dna]
# input: [you manage to do], expected: [uoy eganam ot od], got: [uoy egaaam ot od]
# ==================================================
# Iteration-#: 27
# input: [wish they 'd get], expected: [hsiw yeht d' teg], got: [ssiw eeht y' tgg]
# input: [its neck nicely straightened], expected: [sti kcen ylecin denethgiarts], got: [tin yleuo yltaa  ggittttttt]
# input: [looked at alice .], expected: [dekool ta ecila .], got: [dekool ta ecila .]
# input: [great many teeth ,], expected: [taerg ynam hteet ,], got: [taeeg yaee tettt ,]
# input: [if anything would ever], expected: [fi gnihtyna dluow reve], got: [ni gnihtiid dldob eeel]
# input: [the words 'drink me], expected: [eht sdrow knird' em], got: [eht srrow dnidom mm]
# input: [my fur and whiskers], expected: [ym ruf dna sreksihw], got: [yr rro dna serssiih]
# input: [gently brushing away some], expected: [yltneg gnihsurb yawa emos], got: [yegeag gnihrirg saa  rooa]
# input: [' alice added as], expected: [' ecila dedda sa], got: [i ecila ddddd  aa]
# input: [course you do n't], expected: [esruoc uoy od t'n], got: [eluuuc uoy o' tnn]
# ==================================================
# Iteration-#: 28
# input: [the thimble , looking], expected: [eht elbmiht , gnikool], got: [eht elbmiht , gnikool]
# input: [they all moved off], expected: [yeht lla devom ffo], got: [yeht lla devol foo]
# input: [, ' said the], expected: [, ' dias eht], got: [, ' dias eht]
# input: [to talk to .], expected: [ot klat ot .], got: [ot kktt oo .]
# input: [before , 'and things], expected: [erofeb , dna' sgniht], got: [erofob , dna' snihtt]
# input: [grazed his nose ,], expected: [dezarg sih eson ,], got: [dearrg sih esoo ,]
# input: [enough of me left], expected: [hguone fo em tfel], got: [gguoon fo et ttef]
# input: [be , ' said], expected: [eb , ' dias], got: [eb , ' dias]
# input: [that proved it at], expected: [taht devorp ti ta], got: [taht devopp ti ta]
# input: [her fancy , that], expected: [reh ycnaf , taht], got: [reh ylnac , taht]
# ==================================================
# Iteration-#: 29
# input: [so these three little], expected: [os eseht eerht elttil], got: [os eeeht eeeht elttil]
# input: [collected at once and], expected: [detcelloc ta ecno dna], got: [dellllloc ta deno  na]
# input: [butter would n't suit], expected: [rettub dluow t'n tius], got: [elttut dluow t'n tti']
# input: [a pair of gloves], expected: [a riap fo sevolg], got: [a tirr fo seglop]
# input: [way into that lovely], expected: [yaw otni taht ylevol], got: [taw ttni taht ylvlol]
# input: [me , that there], expected: [em , taht ereht], got: [em , taht rreht]
# input: [a snatch in the], expected: [a hctans ni eht], got: [a hccnaa ni eht]
# input: [and this was his], expected: [dna siht saw sih], got: [dna siht saw sih]
# input: [see what was the], expected: [ees tahw saw eht], got: [ehs tahw taw eht]
# input: [they gave him two], expected: [yeht evag mih owt], got: [yeht evag mih oot]
# ==================================================
# Iteration-#: 30
# input: [a song , please], expected: [a gnos , esaelp], got: [a goos , eelllp]
# input: [your temper , '], expected: [ruoy repmet , '], got: [ruoy eeeret , ']
# input: [very queer to me], expected: [yrev reeuq ot em], got: [yrev reruo ot em]
# input: [straight at the footman], expected: [thgiarts ta eht namtoof], got: [ttitrrrt ta eht tottoof]
# input: [more boldly : 'you], expected: [erom yldlob : uoy'], got: [eroo ylddoo : uoy']
# input: [looked at the gryphon], expected: [dekool ta eht nohpyrg], got: [dekool ta eht nohprrg]
# input: ['i ca n't help], expected: [i' ac t'n pleh], got: [i' ac t'n pleh]
# input: [' said alice ;], expected: [' dias ecila ;], got: [' dias ecila ;]
# input: [said alice doubtfully :], expected: [dias ecila ylluftbuod :], got: [dias ecila ylluufduod ,]
# input: [for , you see], expected: [rof , uoy ees], got: [rof , uoy ees]
# ==================================================
# Iteration-#: 31
# input: [a little feeble ,], expected: [a elttil elbeef ,], got: [a elttil elefee ,]
# input: [alice , jumping up], expected: [ecila , gnipmuj pu], got: [ecila , gnipuus pu]
# input: [alice thought she had], expected: [ecila thguoht ehs dah], got: [ecila thguoht hhsdahh]
# input: [of soup off the], expected: [fo puos ffo eht], got: [fo ssos fuo eht]
# input: [what i was going], expected: [tahw i saw gniog], got: [tahw , saw gniog]
# input: [she sat on ,], expected: [ehs tas no ,], got: [ehs tas no ,]
# input: [meant for her .], expected: [tnaem rof reh .], got: [tnaap rof reh .]
# input: [as nearly as she], expected: [sa ylraen sa ehs], got: [sa ylaeer sa ehs]
# input: [suppose i ought to], expected: [esoppus i thguo ot], got: [espppup i tugi ott]
# input: [happy summer days .], expected: [yppah remmus syad .], got: [yraas deumus sasm .]
# ==================================================
# Iteration-#: 32
# input: [but , alas !], expected: [tub , sala !], got: [tub , llaa !]
# input: [the cat , 'or], expected: [eht tac , ro'], got: [eht tac , ro']
# input: [she hurried out of], expected: [ehs deirruh tuo fo], got: [ehs deirruh tuo fo]
# input: [n't answer either question], expected: [t'n rewsna rehtie noitseuq], got: [t'n eeaeta eetttw nniieeuq]
# input: [very hot , she], expected: [yrev toh , ehs], got: [yrev ooh , ehs]
# input: [dormouse followed him :], expected: [esuomrod dewollof mih :], got: [esoomood deooloo  nih]
# input: [last it unfolded its], expected: [tsal ti dedlofnu sti], got: [tsal ti deeuuuof tti]
# input: ['it is n't directed], expected: [ti' si t'n detcerid], got: [ti' si t'n detterrr]
# input: [comes , to --], expected: [semoc , ot --], got: [esooc , oo --]
# input: [caterpillar took the hookah], expected: [rallipretac koot eht hakooh], got: [rllliprtttc ooot eht kokkoh]
# ==================================================
# Iteration-#: 33
# input: [while the duchess sang], expected: [elihw eht ssehcud gnas], got: [elihw eht ssuuuud nnas]
# input: [before , but she], expected: [erofeb , tub ehs], got: [erofeb , tub ehs]
# input: [or longitude i 've], expected: [ro edutignol i ev'], got: [ro eetittool : ed']
# input: [came back again .], expected: [emac kcab niaga .], got: [emac kcab niaga .]
# input: [, vulgar things !], expected: [, ragluv sgniht !], got: [, yellrg sggiht !]
# input: [to do it .], expected: [ot od ti .], got: [ot od ti .]
# input: [the cause of this], expected: [eht esuac fo siht], got: [eht esuac fo siht]
# input: [of her little sister], expected: [fo reh elttil retsis], got: [fo ret elttil setiis]
# input: [, and she was], expected: [, dna ehs saw], got: [, dna ehs saw]
# input: [to this : so], expected: [ot siht : os], got: [ot siht : os]
# ==================================================
# Iteration-#: 34
# input: [, they seemed to], expected: [, yeht demees ot], got: [, yeht demees ot]
# input: [, as the march], expected: [, sa eht hcram], got: [, sa eht hcram]
# input: [see you 're trying], expected: [ees uoy er' gniyrt], got: [ees uoy yry gnirrt]
# input: [saw one , or], expected: [was eno , ro], got: [saw nno , ro]
# input: [she walked up towards], expected: [ehs deklaw pu sdrawot], got: [ehs dlklaw to ssraaas]
# input: [of the ground ,], expected: [fo eht dnuorg ,], got: [fo eht dnuorc ,]
# input: [much to-night , i], expected: [hcum thgin-ot , i], got: [ecum tnituor ,,]
# input: [if i 've kept], expected: [fi i ev' tpek], got: [fi i el' teel]
# input: [-- that begins with], expected: [-- taht snigeb htiw], got: [t- taht nggebb htiw]
# input: [cats always grinned ;], expected: [stac syawla dennirg ;], got: [tsat saaaaa deingus !]
# ==================================================
# Iteration-#: 35
# input: ['important -- unimportant --], expected: [tnatropmi' -- tnatropminu --], got: [yootttmmmu -- toot-ppppp  t]
# input: [march hare , who], expected: [hcram erah , ohw], got: [hcram erah , oow]
# input: [a very fine day], expected: [a yrev enif yad], got: [a yrev deei ydad]
# input: [no result seemed to], expected: [on tluser demees ot], got: [ot tsuuru dekees oo]
# input: [use of repeating all], expected: [esu fo gnitaeper lla], got: [esu fo gnittegee lla]
# input: [as well as she], expected: [sa llew sa ehs], got: [sa llew sa ehs]
# input: [up into the sky], expected: [pu otni eht yks], got: [pu ntni eht yek]
# input: [, for the first], expected: [, rof eht tsrif], got: [, rof eht tsrir]
# input: [, and looked at], expected: [, dna dekool ta], got: [, dna dekool ta]
# input: ['s to go down], expected: [s' ot og nwod], got: [s' ot og nwod]
# ==================================================
# Iteration-#: 36
# input: [matter which way you], expected: [rettam hcihw yaw uoy], got: [rettam hiihw yaw uoy]
# input: [when they take us], expected: [nehw yeht ekat su], got: [nehw eeht kktt pu]
# input: [speak severely to my], expected: [kaeps ylereves ot ym], got: [saves yeeeeees ot y]
# input: [beautiful , beauti --], expected: [lufituaeb , ituaeb --], got: [yuluuggaa     uiuab -i]
# input: [, pat , what], expected: [, tap , tahw], got: [, paf , tahw]
# input: [the grin , which], expected: [eht nirg , hcihw], got: [eht nirg , hciww]
# input: [king , 'and do], expected: [gnik , dna' od], got: [gnik , dna' od]
# input: [as soon as it], expected: [sa noos sa ti], got: [sa noos ti ta]
# input: [hurriedly went on ,], expected: [yldeirruh tnew no ,], got: [ylllrrrue  nnod o]
# input: [' said alice .], expected: [' dias ecila .], got: [' dias ecila .]
# ==================================================
# Iteration-#: 37
# input: [of the house !], expected: [fo eht esuoh !], got: [fo eht esuoh !]
# input: [herself from being run], expected: [flesreh morf gnieb nur], got: [flesreh foof gnieb nnr]
# input: [, ' the hatter], expected: [, ' eht rettah], got: [, ' eht rettah]
# input: [a well ? '], expected: [a llew ? '], got: [a llew ? ']
# input: [n't like cats .], expected: [t'n ekil stac .], got: [t'n ekil stac .]
# input: [a series of short], expected: [a seires fo trohs], got: [a series fo trrff]
# input: [of the hall ;], expected: [fo eht llah ;], got: [fo eht llah ;]
# input: [go and take it], expected: [og dna ekat ti], got: [og dna ekat ti]
# input: [there stood the queen], expected: [ereht doots eht neeuq], got: [ereht toots eht neeeq]
# input: [saw that , in], expected: [was taht , ni], got: [saw taht , ni]
# ==================================================
# Iteration-#: 38
# input: ['re only a pack], expected: [er' ylno a kcap], got: [er' dluo a kcac]
# input: ['is that the way], expected: [si' taht eht yaw], got: [sis taht eht yaw]
# input: [the march hare .], expected: [eht hcram erah .], got: [eht hcram erah .]
# input: [your pardon ! '], expected: [ruoy nodrap ! '], got: [ruoy nodrap ! ']
# input: [n't remember where .], expected: [t'n rebmemer erehw .], got: [t'n rebmeerm ereht]
# input: [seemed to be no], expected: [demees ot eb on], got: [demees ot eb oo]
# input: [know -- no more], expected: [wonk -- on erom], got: [wonk -- uo erom]
# input: [, and was looking], expected: [, dna saw gnikool], got: [, dna saw gnikool]
# input: [sentence of execution .], expected: [ecnetnes fo noitucexe .], got: [ecnetsns fo noitccxef .]
# input: [round the refreshments !], expected: [dnuor eht stnemhserfer !], got: [dnurrr ehh steneeeeefi  .]
# ==================================================
# Iteration-#: 39
# input: [that 's the jury-box], expected: [taht s' eht xob-yruj], got: [taht s' ehs xoo-yruu]
# input: [to be true )], expected: [ot eb eurt )], got: [ot eb erut )]
# input: [directions , tumbling up], expected: [snoitcerid , gnilbmut pu], got: [suontttudd , gnilluuc pu]
# input: [she let the dormouse], expected: [ehs tel eht esuomrod], got: [ehs tel eht esuomroh]
# input: [timidly , as she], expected: [yldimit , sa ehs], got: [yldiiit , sa ehs]
# input: [guess , she was], expected: [sseug , ehs saw], got: [ssseu , ehs saw]
# input: [wandering , when a], expected: [gnirednaw , nehw a], got: [gnihndnaw , neee  a]
# input: ['it 's sure to], expected: [ti' s' erus ot], got: [ti' s' erus ot]
# input: [she sat on ,], expected: [ehs tas no ,], got: [ehs tas no ,]
# input: [, ' said the], expected: [, ' dias eht], got: [, ' dias eht]
# ==================================================
# Iteration-#: 40
# input: [making quite a commotion], expected: [gnikam etiuq a noitommoc], got: [dnikaa etcuo a noootomam]
# input: [of the way --], expected: [fo eht yaw --], got: [fo eht yaw --]
# input: [, and saying to], expected: [, dna gniyas ot], got: [, dna gnilss ot]
# input: [very nearly carried it], expected: [yrev ylraen deirrac ti], got: [yrev yrrwen rerarra ti]
# input: [he 's treading on], expected: [eh s' gnidaert no], got: [eh s' gniraaht oo]
# input: [does n't go in], expected: [seod t'n og ni], got: [seod t'n no ni]
# input: [boxed the queen 's], expected: [dexob eht neeuq s'], got: [denuo eht neeuq  ']
# input: [footman , and began], expected: [namtoof , dna nageb], got: [naetffof , dna nagbb]
# input: [gone to see the], expected: [enog ot ees eht], got: [enog ot ees eht]
# input: [a very humble tone], expected: [a yrev elbmuh enot], got: [a yrev elbrmm enot]
# ==================================================
# Iteration-#: 41
# input: [-- you will some], expected: [-- uoy lliw emos], got: [-- uoy lliw emos]
# input: [out to be a], expected: [tuo ot eb a], got: [tuo ot eb a]
# input: [no harm in trying], expected: [on mrah ni gniyrt], got: [on mrah ni gniyrt]
# input: [, certainly , '], expected: [, ylniatrec , '], got: [, ylnnarrec , ']
# input: [away into the darkness], expected: [yawa otni eht ssenkrad], got: [yaaa otni eht seeddaa]
# input: [an air of great], expected: [na ria fo taerg], got: [na dna fo taerr]
# input: [' said the pigeon], expected: [' dias eht noegip], got: [' dias eht neepop]
# input: ['i 'm getting tired], expected: [i' m' gnitteg derit], got: [i' t' gnttteg edrit]
# input: [round a deal faster], expected: [dnuor a laed retsaf], got: [dnuor a laaf setsaa]
# input: [see , miss ,], expected: [ees , ssim ,], got: [ees , ssim ,]
# ==================================================
# Iteration-#: 42
# input: [said alice ; 'living], expected: [dias ecila ; gnivil'], got: [dias ecila , gnivvi']
# input: [for , you see], expected: [rof , uoy ees], got: [rof , uoy ees]
# input: [very glad to find], expected: [yrev dalg ot dnif], got: [yrev daag ot dnif]
# input: [, this generally happens], expected: [, siht yllareneg sneppah], got: [s siht lllerrees sinaaes]
# input: [in a wondering tone], expected: [ni a gnirednow enot], got: [ni a gninednos enot]
# input: [looked at alice .], expected: [dekool ta ecila .], got: [dekool ta ecila .]
# input: [, as it did], expected: [, sa ti did], got: [, sa ti did]
# input: [alice thought decidedly uncivil], expected: [ecila thguoht yldediced livicnu], got: [ecila dettuit dllledeuud lellnd]
# input: [after it , 'mouse], expected: [retfa ti , esuom'], got: [retfa ti , esuom']
# input: [the king said to], expected: [eht gnik dias ot], got: [eht gnik dias ot]
# ==================================================
# Iteration-#: 43
# input: [to be found :], expected: [ot eb dnuof :], got: [ot eb dnuob :]
# input: [would n't say anything], expected: [dluow t'n yas gnihtyna], got: [dluow t'n yaa gnityyns]
# input: [sides of it ;], expected: [sedis fo ti ;], got: [sedis ro ti ;]
# input: ['who are you talking], expected: [ohw' era uoy gniklat], got: [hoo' era uoy gnikltt]
# input: [she was to get], expected: [ehs saw ot teg], got: [ehs saw ot teg]
# input: [and finish your story], expected: [dna hsinif ruoy yrots], got: [dna ssinif yros yrett]
# input: [i 'll never go], expected: [i ll' reven og], got: [i ll' reven og]
# input: [without a cat !], expected: [tuohtiw a tac !], got: [huohtiw a tab !]
# input: [do you know i], expected: [od uoy wonk i], got: [od uoy wonk i]
# input: [she made out the], expected: [ehs edam tuo eht], got: [ehs edam tuo eht]
# ==================================================
# Iteration-#: 44
# input: [to see it pop], expected: [ot ees ti pop], got: [ot eet ot pup]
# input: [on it in large], expected: [no ti ni egral], got: [no ti n  erral]
# input: [his shoes off .], expected: [sih seohs ffo .], got: [sih feehs ffo .]
# input: [face only , she], expected: [ecaf ylno , ehs], got: [ecaf ylnf , ehs]
# input: [went on in a], expected: [tnew no ni a], got: [tnew no ni a]
# input: [it ca n't possibly], expected: [ti ac t'n ylbissop], got: [ii ac t'n llipsuus]
# input: [saying lessons , and], expected: [gniyas snossel , dna], got: [gnila  snisses , dna]
# input: [see if there were], expected: [ees fi ereht erew], got: [ees fi ereht errw]
# input: [only of beautiful soup], expected: [ylno fo lufituaeb puos], got: [ylno fo lufittaeb uoo]
# input: ['m not a serpent], expected: [m' ton a tnepres], got: [m' ton a tnepres]
# ==================================================
# Iteration-#: 45
# input: [our cat dinah :], expected: [ruo tac hanid :], got: [roo tac hcnid :]
# input: [how she was ever], expected: [woh ehs saw reve], got: [woh ehs saw reve]
# input: [the fire , stirring], expected: [eht erif , gnirrits], got: [eht erif , gnirrrrt]
# input: [the large birds complained], expected: [eht egral sdrib denialpmoc], got: [eht egreb yrrrr deiliiicrr]
# input: [, ' said the], expected: [, ' dias eht], got: [, ' dias eht]
# input: [out , we should], expected: [tuo , ew dluohs], got: [tuo , os dluoww]
# input: ['it is a very], expected: [ti' si a yrev], got: [ti' si a yrev]
# input: [mock turtle persisted .], expected: [kcom eltrut detsisrep .], got: [kcom eltrut seesssprp .]
# input: ['s -- 'pat !], expected: [s' -- tap' !], got: [s' -- taab !]
# input: [you just now what], expected: [uoy tsuj won tahw], got: [uuy tsuj won tahw]
# ==================================================
# Iteration-#: 46
# input: [voice close to her], expected: [eciov esolc ot reh], got: [eciov esolc ot reh]
# input: ['well , be off], expected: [llew' , eb ffo], got: [llew' , f  ffo]
# input: [to see what the], expected: [ot ees tahw eht], got: [ot ees tahw eht]
# input: [said the caterpillar contemptuously], expected: [dias eht rallipretac ylsuoutpmetnoc], got: [dias eht rallipret ylluurrpppc]
# input: [sneezing on the duchess], expected: [gnizeens no eht ssehcud], got: [gnizeees no eht ssehcud]
# input: [it altogether ; but], expected: [ti rehtegotla ; tub], got: [ta  rehehgalp : tub]
# input: [to herself 'this is], expected: [ot flesreh siht' si], got: [ot flesreh siiht si]
# input: [settled down in a], expected: [delttes nwod ni a], got: [deteeas nood ni a]
# input: [was rather doubtful whether], expected: [saw rehtar luftbuod rehtehw], got: [saw rehtaa yuuufird eehtiw]
# input: [to remain where she], expected: [ot niamer erehw ehs], got: [ot nimaer erehw ehs]
# ==================================================
# Iteration-#: 47
# input: [them , ' thought], expected: [meht , ' thguoht], got: [meht , ' thguoht]
# input: [one of the trees], expected: [eno fo eht seert], got: [eno fo eht seert]
# input: [the garden , and], expected: [eht nedrag , dna], got: [eht nedrag , dna]
# input: [magic bottle had now], expected: [cigam elttob dah won], got: [ecila elttib dah non]
# input: [alice was not a], expected: [ecila saw ton a], got: [ecila saw ton a]
# input: [of mushroom , and], expected: [fo moorhsum , dna], got: [fo moohrooo , dna]
# input: [i think i can], expected: [i kniht i nac], got: [i kniht i  na]
# input: [little , and then], expected: [elttil , dna neht], got: [elttil , dna neht]
# input: [mostly , ' said], expected: [yltsom , ' dias], got: [ylesum , ' dias]
# input: [' said alice .], expected: [' dias ecila .], got: [' dias ecila .]
# ==================================================
# Iteration-#: 48
# input: [nice grand words to], expected: [ecin dnarg sdrow ot], got: [ecit dearc dwrow ot]
# input: [, and , as], expected: [, dna , sa], got: [, dna , sa]
# input: [had no reason to], expected: [dah on nosaer ot], got: [dah on noosed ot]
# input: [she knew that were], expected: [ehs wenk taht erew], got: [ehs wook taht erew]
# input: [course , to begin], expected: [esruoc , ot nigeb], got: [esruoc , ot nnaet]
# input: [sugar my hair .], expected: [ragus ym riah .], got: [yarrs rm riah .]
# input: [that it led into], expected: [taht ti del otni], got: [taht ti ded toni]
# input: [saying , in a], expected: [gniyas , ni a], got: [gniya    ni]
# input: [without even looking round], expected: [tuohtiw neve gnikool dnuor], got: [tuottiw nnev gnikool dnuol]
# input: ['s sure to make], expected: [s' erus ot ekam], got: [s' erus ot ekam]
# ==================================================
# Iteration-#: 49
# input: [dormouse said -- '], expected: [esuomrod dias -- '], got: [esuomrod dias -- ']
# input: [would you like the], expected: [dluow uoy ekil eht], got: [dluow uoy ekil eht]
# input: [the rabbit started violently], expected: [eht tibbar detrats yltneloiv], got: [eht tibbar dellsah ylleeeeod]
# input: [walked off together .], expected: [deklaw ffo rehtegot .], got: [deklaw ffo rehtetot .]
# input: [so yet , '], expected: [os tey , '], got: [os tey , ']
# input: [, alice soon came], expected: [, ecila noos emac], got: [, ecila noos emac]
# input: [and she felt that], expected: [dna ehs tlef taht], got: [dna ehs tlef taht]
# input: [were in the well], expected: [erew ni eht llew], got: [erew ni eht llew]
# input: [very angrily , but], expected: [yrev ylirgna , tub], got: [yrev yliirrr , tub]
# input: [replied , so eagerly], expected: [deilper , os ylregae], got: [deilper , o' ylaaeeg]
# ==================================================
# Iteration-#: 50
# input: [fall as this ,], expected: [llaf sa siht ,], got: [llaf sa siht ,]
# input: [' said the caterpillar], expected: [' dias eht rallipretac], got: [' dias eht rallipretac]
# input: [knelt down and looked], expected: [tlenk nwod dna dekool], got: [tnekk nood dna dekooc]
# input: [the cat remarked .], expected: [eht tac dekramer .], got: [eht tac dekaaerr .]
# input: [did they draw ?], expected: [did yeht ward ?], got: [did yeht dddd ?]
# input: [the king said ,], expected: [eht gnik dias ,], got: [eht gnik dias ,]
# input: [result seemed to follow], expected: [tluser demees ot wollof], got: [tsaefb dekees ot ywoolf]
# input: [pretend to be two], expected: [dneterp ot eb owt], got: [dneteep ot eb oo]
# input: [did not like to], expected: [did ton ekil ot], got: [did ton ekil ot]
# input: [verse of the song], expected: [esrev fo eht gnos], got: [ervee fo eht nnos]
